# %%
import importlib
import plotter
importlib.reload(plotter)
from plotter import Analyser
from plotter import compare_schedulers

# %%
fcfs = Analyser('fcfs_gantt_data.csv','fcfs_meta_data.csv', "FCFS")
fcfs.plot_gantt_chart()
fcfs.plot_individual_gantt_chart()
fcfs.evaluate_performance()
# Out:
# Average waiting time of the threads =  142.8 ms
# Peak waiting time of the threads =  215 ms
# Average burst time of the threads =  100.0 ms
#
# Average Response Time =  144.4  ms
# Context Switch Overhead =  5

# %%
sjt = Analyser('sjt_gantt_data.csv','sjt_meta_data.csv', 'SJT')
sjt.plot_gantt_chart()
sjt.plot_individual_gantt_chart()
sjt.evaluate_performance()
# Out:
# Average waiting time of the threads =  123.2 ms
# Peak waiting time of the threads =  231 ms
# Average burst time of the threads =  100.0 ms
#
# Average Response Time =  125.0  ms
# Context Switch Overhead =  5

# %%
strf = Analyser('strf_gantt_data.csv','strf_meta_data.csv',"STRF")
strf.plot_gantt_chart()
strf.plot_individual_gantt_chart()
strf.evaluate_performance()
# Out:
# Average waiting time of the threads =  97.4 ms
# Peak waiting time of the threads =  300 ms
# Average burst time of the threads =  100.0 ms
#
# Average Response Time =  31.4  ms
# Context Switch Overhead =  7

# %%
rr = Analyser('rr_gantt_data.csv','rr_meta_data.csv',"RR")
rr.plot_gantt_chart()
rr.plot_individual_gantt_chart()
rr.evaluate_performance()
# Out:
# Average waiting time of the threads =  215.0 ms
# Peak waiting time of the threads =  278 ms
# Average burst time of the threads =  100.0 ms
#
# Average Response Time =  90.6  ms
# Context Switch Overhead =  11

# %%
ps = Analyser('ps_gantt_data.csv','ps_meta_data.csv',"PS")
ps.plot_gantt_chart()
ps.plot_individual_gantt_chart()
ps.evaluate_performance()
# Out:
# Average waiting time of the threads =  124.0 ms
# Peak waiting time of the threads =  286 ms
# Average burst time of the threads =  100.0 ms
#
# Average Response Time =  76.8  ms
# Context Switch Overhead =  6

# %%
compare_schedulers([fcfs, sjt, strf, rr, ps])
# Out:
# +-----------------+----------------------+-------------------+-----------------------+----------------------------+
# | Scheduling Algo | Average Waiting Time | Peak Waiting Time | Average Response Time | Context Switching Overhead |
# +-----------------+----------------------+-------------------+-----------------------+----------------------------+
# |      FCFS       |        142.8         |        215        |         144.4         |             5              |
# |       SJT       |        123.2         |        231        |         125.0         |             5              |
# |      STRF       |         97.4         |        300        |         31.4          |             7              |
# |       RR        |        215.0         |        278        |         90.6          |             11             |
# |       PS        |        124.0         |        286        |         76.8          |             6              |
# ...
